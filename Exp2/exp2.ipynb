# %% [markdown]
# # Exp2 : Implementation of an End-to-End Machine Learning Data Pipeline
# ### Name : Jash Mewada Roll no : 109 batch 2

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
import seaborn as sns

# %%
titanic_dataset = sns.load_dataset('titanic')
print(f"Number of rows and columns {titanic_dataset.shape}")
titanic_dataset.columns
# Out:
# Number of rows and columns (891, 15)
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
print("\n\nFirst 5 rows\n\n",titanic_dataset.head())
print("\n\nFirst 5 columns\n\n",titanic_dataset.tail)
# Out:
# First 5 rows
#
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
#
# First 5 columns
#
#  <bound method NDFrame.tail of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# ...

# %%
titanic_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic_dataset.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
missing = titanic_dataset.isnull().sum()
print(missing)
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic_dataset1 = titanic_dataset.drop(columns=['deck'])

# %%
titanic_dataset1['age'].fillna(titanic_dataset1['age'].median(),inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21468\93706887.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_dataset1['age'].fillna(titanic_dataset1['age'].median(),inplace=True)

# %%
missing = titanic_dataset1.isnull().sum()
print(missing)
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
titanic_dataset1['embark_town'].dtype
# Out:
# dtype('O')

# %%
titanic_dataset1['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
titanic_dataset1['embark_town'].fillna(titanic_dataset1['embark_town'].mode()[0],inplace=True  )
titanic_dataset1.isnull().sum()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21468\3160786170.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_dataset1['embark_town'].fillna(titanic_dataset1['embark_town'].mode()[0],inplace=True  )
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
print(titanic_dataset1['embarked'].dtype)
print(titanic_dataset1['embarked'].unique())
titanic_dataset1['embarked'].fillna(titanic_dataset1['embarked'].mode()[0],inplace=True)
# Out:
# object
# ['S' 'C' 'Q' nan]
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21468\3909112950.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_dataset1['embarked'].fillna(titanic_dataset1['embarked'].mode()[0],inplace=True)

# %%
print(titanic_dataset1.isnull().sum())
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
l = LabelEncoder()
titanic_dataset1['sex']=l.fit_transform(titanic_dataset1['sex'])
titanic_dataset1['embarked']=l.fit_transform(titanic_dataset1['embarked'])
print(titanic_dataset1.head())
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500         2  Third    man
# 1         1       1    0  38.0      1      0  71.2833         0  First  woman
# 2         1       3    0  26.0      0      0   7.9250         2  Third  woman
# 3         1       1    0  35.0      1      0  53.1000         2  First  woman
# 4         0       3    1  35.0      0      0   8.0500         2  Third    man
#
#    adult_male  embark_town alive  alone
# 0        True  Southampton    no  False
# 1       False    Cherbourg   yes  False
# 2       False  Southampton   yes   True
# 3       False  Southampton   yes  False
# 4        True  Southampton    no   True

# %%
titanic_dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    int32
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    int32
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  891 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int32(2), int64(4), object(3)
# memory usage: 72.5+ KB

# %%
data = titanic_dataset1[['pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'survived']]
X = data[['pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked']]
Y = data['survived']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)
model = LogisticRegression(max_iter=1000)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_predict = model.predict(X_test)
acc = accuracy_score(y_test,y_predict)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.8100558659217877

# %%
new_pass = pd.DataFrame({
    "pclass": [3],
    "sex": ["male"],
    "age": [22],
    "sibSp": [1],
    "parch": [0],
    "fare": [7.25],
    "embarked": ["S"]
})

new_pass_encoded = pd.get_dummies(new_pass)
new_pass_encoded = new_pass_encoded.reindex(columns = X_train.columns, fill_value = 0)

# %%
prediction = model.predict(new_pass_encoded)
print("Survived" if prediction[0] == 1 else "Not Survived")
# Out:
# Survived

# %%
new_pass2 = pd.DataFrame({
    'pclass':[1,3,2],
    'sex':[1,0,1],           # 1 = male, 0 = female (from LabelEncoder)
    'age':[38,45,14],
    'sibsp':[0,1,0],         # Added missing column
    'parch':[0,0,2],         # Added missing column
    'fare':[80.0,8.05,20.0],
    'embarked':[0,2,1]       # 0 = C, 1 = Q, 2 = S (from LabelEncoder)
})

new_pass2_en = new_pass2.reindex(columns = X_train.columns, fill_value = 0)

# %%
predicios = model.predict(new_pass2_en)
for i ,pred in enumerate(predicios):
    print(f"Passanger {i+1}:","Survived" if pred == 1 else "Not Survived")
# Out:
# Passanger 1: Survived
# Passanger 2: Not Survived
# Passanger 3: Not Survived
